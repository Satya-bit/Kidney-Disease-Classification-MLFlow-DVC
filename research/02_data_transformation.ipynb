# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\satya\\Documents\\data_science_roadmap\\Deep_Learning\\Project\\Kidney-Disease-Classification-MLFlow-DVC\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\satya\\Documents\\data_science_roadmap\\Deep_Learning\\Project\\Kidney-Disease-Classification-MLFlow-DVC'

# %%
#Entity 
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True) 
class DataTransformationConfig:
    root_dir: Path
    data: Path
    split: Path
    train: float
    test: float
    
    # train_data_path: Path
    # test_data_path: Path

# %%
#Config Manager
from src.cnnClassifier.constants import *  #IMPORTING THE TWO CONSTANTS PATH OF CONFIG AND PARAMS FROM CONSTANTS

from src.cnnClassifier.utils.common import read_yaml, create_directories #Importing from utils the common functions like read_yaml and creat_directories.

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])
        

    def get_data_transformation_config(self) -> DataTransformationConfig:
        data_transformation = self.config.data_transformation
        data_ingestion = self.config.data_ingestion  # Get data ingestion config
        params=self.params
        
        data = os.path.join(data_ingestion.unzip_dir, "dataset")
        
        create_directories([Path(data_transformation.root_dir)])

        data_transformation_config = DataTransformationConfig(
            root_dir=Path(data_transformation.root_dir),
            data=Path(data),
            split=Path(data_transformation.split),
            train=params.TRAIN,
            test=params.TEST
        )
        
        return data_transformation_config

# %%
import os
import cv2 as cv
import numpy as np
import python_splitter
import shutil
import random
import imgaug.augmenters as iaa

class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config
        self.data = self.config.data
        self.split = self.config.split
        self.train = self.config.train
        self.test = self.config.test

    @staticmethod
    def watershed(image_path):
        img = cv.imread(image_path)
        if img is None:
            print(f"Warning: Unable to read image at {image_path}")
            return None

        gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
        ret, thresh = cv.threshold(gray, 0, 255, cv.THRESH_BINARY_INV + cv.THRESH_OTSU)
        kernel = np.ones((3, 3), np.uint8)
        opening = cv.morphologyEx(thresh, cv.MORPH_OPEN, kernel, iterations=2)
        sure_bg = cv.dilate(opening, kernel, iterations=3)
        dist_transform = cv.distanceTransform(opening, cv.DIST_L2, 5)
        ret, sure_fg = cv.threshold(dist_transform, 0.001 * dist_transform.max(), 255, 0)
        sure_fg = np.uint8(sure_fg)
        unknown = cv.subtract(sure_bg, sure_fg)
        ret, markers = cv.connectedComponents(sure_fg)
        markers = markers + 1
        markers[unknown == 255] = 0
        markers = cv.watershed(img, markers)
        img[markers == -1] = [255, 0, 0]
        return img

    @staticmethod
    def augment_and_save_images(folder_path):
        """Augments all images in the specified folder"""
        image_files = [f for f in os.listdir(folder_path) 
                     if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        
        if not image_files:
            print("No images found in the specified folder.")
            return

        print(f"Found {len(image_files)} images. Augmenting...")

        for image_file in image_files:
            image_path = os.path.join(folder_path, image_file)
            image = cv.imread(image_path)
            if image is None:
                print(f"Error: Unable to read {image_file}")
                continue

            augmenters = [
                iaa.Affine(rotate=(-15, 15)),
                iaa.Fliplr(0.5),
                iaa.Flipud(0.2),
                iaa.Affine(translate_percent={"x": (-0.1, 0.1), "y": (-0.1, 0.1)}),
                iaa.Affine(shear=(-8, 8)),
                iaa.Affine(scale=(0.9, 1.1)),
                iaa.Multiply((0.8, 1.2)),
                iaa.LinearContrast((0.8, 1.2)),
                iaa.GaussianBlur(sigma=(0, 0.5))
            ]

            for i in range(3):  # Create 3 augmented versions
                selected = random.sample(augmenters, random.randint(3, 5))
                seq = iaa.Sequential(selected)
                augmented = seq.augment_image(image)
                aug_path = os.path.join(folder_path, f"aug_{i}_{image_file}")
                cv.imwrite(aug_path, augmented)
                print(f"Saved: {aug_path}")

        print("Augmentation complete.")

    def process_and_save_images(self):
        src_dir = str(self.data)
        dest_dir = str(self.config.root_dir)
        
        # Create destination folders
        normal_dir = os.path.join(dest_dir, 'Normal')
        tumor_dir = os.path.join(dest_dir, 'Tumor')
        os.makedirs(normal_dir, exist_ok=True)
        os.makedirs(tumor_dir, exist_ok=True)

        # Process and save original images
        for folder_name in ['Normal', 'Tumor']:
            folder_path = os.path.join(src_dir, folder_name)
            output_folder = normal_dir if folder_name == 'Normal' else tumor_dir

            for filename in os.listdir(folder_path):
                file_path = os.path.join(folder_path, filename)
                if os.path.isfile(file_path) and filename.lower().endswith(('.jpg', '.jpeg', '.png')):
                    processed_img = DataTransformation.watershed(file_path)
                    if processed_img is not None:
                        output_path = os.path.join(output_folder, filename)
                        cv.imwrite(output_path, processed_img)
                        print(f"Processed and saved: {output_path}")

        # Perform train-test split
        python_splitter.split_from_folder(dest_dir, train=self.train, test=self.test)
        
        # Move the split folder if needed
        if os.path.exists('Train_Test_Folder'):
            shutil.move('Train_Test_Folder', str(self.split))
            
        # Augment tumor training images (after split)
        tumor_train_path = os.path.join(str(self.split), 'train', 'Tumor')
        if os.path.exists(tumor_train_path):
            DataTransformation.augment_and_save_images(tumor_train_path) #Accessing the static method wit calling the class name

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.process_and_save_images()  # No parameters needed
except Exception as e:
    raise e
# Out:
# [2025-04-04 13:39:57,665: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-04-04 13:39:57,670: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-04-04 13:39:57,672: INFO: common: created directory at: artifacts]
# [2025-04-04 13:39:57,673: INFO: common: created directory at: artifacts\data_transformation]
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2074).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2075).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2076).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2077).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2078).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2079).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2080).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2081).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2082).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2083).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2084).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2085).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2086).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2087).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2088).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2089).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2090).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2091).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2092).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2093).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2094).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2095).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2096).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2097).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2098).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2099).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2100).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2101).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2102).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2103).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2104).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2105).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2106).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2107).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2108).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2109).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2110).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2111).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2112).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2113).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2114).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2115).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2116).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2117).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2118).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2119).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2120).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2121).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2122).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2123).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2124).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2125).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2126).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2127).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2128).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2129).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2130).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2131).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2132).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2133).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2134).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2135).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2136).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2137).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2138).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2139).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2140).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2141).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2142).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2143).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2144).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2145).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2146).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2147).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2148).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2149).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2150).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2151).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2152).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2153).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2154).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2155).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2156).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2157).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2158).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2159).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2160).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2161).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2162).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2163).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2164).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2165).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2166).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2167).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2168).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2169).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2170).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2171).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2172).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2173).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2174).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2175).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2176).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2177).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2178).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2179).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2180).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2181).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2182).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2183).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2184).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2185).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2186).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2187).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2188).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2189).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2190).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2191).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2192).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2193).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2194).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2195).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2196).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2197).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2198).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2199).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2200).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2201).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2202).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2203).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2204).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2205).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2206).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2207).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2208).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2209).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2210).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2211).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2212).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2213).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2214).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2215).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2216).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2217).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2218).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2219).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2220).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2221).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2222).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2223).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2224).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2225).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2226).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2227).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2228).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2229).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2230).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2231).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2232).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2233).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2234).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2235).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2236).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2237).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2238).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2239).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2240).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2241).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2242).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2243).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2244).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2245).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2246).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2247).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2248).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2249).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2250).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2251).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2252).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2253).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2254).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2255).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2256).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2257).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2258).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2259).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2260).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2261).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2262).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2263).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2264).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2265).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2266).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2267).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2268).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2269).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2270).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2271).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2272).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2273).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2274).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2275).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2276).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2277).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2278).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2279).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2280).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2281).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2282).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2283).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2284).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2285).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2286).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2287).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2288).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2289).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2290).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2291).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2292).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2293).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2294).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2295).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2296).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2297).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2298).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2299).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2300).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2301).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2302).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2303).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2304).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2305).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2306).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2307).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2308).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2309).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2310).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2311).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2312).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2313).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2314).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2315).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2316).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2317).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2318).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2319).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2320).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2321).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2322).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2323).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2324).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2325).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2326).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2327).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2328).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2329).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2330).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2331).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2332).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2333).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2334).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2335).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2336).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2337).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2338).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2339).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2340).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2341).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2342).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2343).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2344).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2345).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2346).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2347).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2348).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2349).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2350).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2351).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2352).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2353).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2354).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2355).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2356).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2357).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2358).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2359).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2360).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2361).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2362).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2363).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2364).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2365).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2366).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2367).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2368).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2369).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2370).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2371).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2372).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2373).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2374).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2375).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2376).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2377).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2378).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2379).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2380).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2381).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2382).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2383).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2384).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2385).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2386).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2387).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2388).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2389).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2390).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2391).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2392).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2393).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2394).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2395).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2396).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2397).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2398).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2399).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2400).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2401).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2402).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2403).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2404).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2405).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2406).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2407).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2408).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2409).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2410).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2411).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2412).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2413).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2414).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2415).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2416).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2417).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2418).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2419).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2420).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2421).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2422).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2423).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2424).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2425).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2426).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2427).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2428).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2429).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2430).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2431).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2432).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2433).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2434).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2435).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2436).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2437).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2438).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2439).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2440).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2441).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2442).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2443).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2444).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2445).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2446).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2447).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2448).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2449).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2450).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2451).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2452).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2453).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2454).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2455).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2456).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2457).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2458).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2459).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2460).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2461).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2462).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2463).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2464).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2465).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2466).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2467).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2468).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2469).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2470).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2471).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2472).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2473).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2474).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2475).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2476).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2477).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2478).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2479).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2480).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2481).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2482).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2483).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2484).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2485).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2486).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2487).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2488).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2489).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2490).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2491).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2492).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2493).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2494).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2495).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2496).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2497).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2498).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2499).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2500).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2501).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2502).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2503).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2504).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2505).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2506).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2507).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2508).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2509).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2510).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2511).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2512).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2513).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2514).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2515).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2516).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2517).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2518).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2519).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2520).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2521).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2522).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2523).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2524).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2525).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2526).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2527).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2528).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2529).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2530).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2531).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2532).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2533).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2534).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2535).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2536).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2537).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2538).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2539).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2540).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2541).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2542).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2543).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2544).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2545).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2546).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2547).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2548).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2549).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2550).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2551).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2552).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2553).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2554).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2555).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2556).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2557).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2558).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2559).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2560).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2561).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2562).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2563).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2564).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2565).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2566).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2567).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2568).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2569).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2570).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2571).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2572).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2573).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2574).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2575).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2576).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2577).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2578).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2579).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2580).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2581).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2582).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2583).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2584).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2585).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2586).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2587).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2588).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2589).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2590).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2591).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2592).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2593).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2594).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2595).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2596).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2597).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2598).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2599).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2600).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2601).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2602).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2603).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2604).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2605).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2606).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2607).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2608).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2609).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2610).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2611).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2612).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2613).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2614).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2615).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2616).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2617).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2618).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2619).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2620).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2621).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2622).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2623).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2624).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2625).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2626).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2627).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2628).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2629).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2630).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2631).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2632).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2633).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2634).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2635).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2636).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2637).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2638).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2639).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2640).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2641).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2642).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2643).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2644).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2645).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2646).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2647).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2648).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2649).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2650).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2651).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2652).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2653).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2654).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2655).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2656).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2657).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2658).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2659).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2660).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2661).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2662).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2663).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2664).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2665).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2666).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2667).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2668).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2669).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2670).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2671).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2672).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2673).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2674).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2675).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2676).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2677).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2678).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2679).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2680).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2681).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2682).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2683).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2684).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2685).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2686).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2687).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2688).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2689).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2690).jpg
# Processed and saved: artifacts\data_transformation\Normal\Normal- (2691).jpg
# ...
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (921).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (923).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (923).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (923).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (924).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (924).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (924).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (925).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (925).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (925).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (926).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (926).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (926).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (927).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (927).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (927).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (928).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (928).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (928).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (929).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (929).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (929).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (93).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (93).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (93).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (930).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (930).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (930).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (931).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (931).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (931).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (932).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (932).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (932).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (933).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (933).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (933).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (934).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (934).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (934).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (936).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (936).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (936).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (937).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (937).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (937).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (938).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (938).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (938).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (939).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (939).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (939).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (94).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (94).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (94).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (940).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (940).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (940).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (941).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (941).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (941).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (942).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (942).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (942).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (943).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (943).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (943).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (944).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (944).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (944).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (946).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (946).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (946).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (947).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (947).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (947).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (948).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (948).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (948).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (949).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (949).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (949).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (95).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (95).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (95).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (950).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (950).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (950).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (951).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (951).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (951).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (952).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (952).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (952).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (954).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (954).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (954).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (955).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (955).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (955).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (956).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (956).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (956).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (957).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (957).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (957).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (958).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (958).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (958).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (96).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (96).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (96).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (960).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (960).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (960).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (961).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (961).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (961).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (962).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (962).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (962).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (963).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (963).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (963).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (964).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (964).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (964).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (968).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (968).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (968).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (97).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (97).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (97).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (970).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (970).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (970).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (971).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (971).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (971).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (972).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (972).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (972).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (974).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (974).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (974).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (975).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (975).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (975).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (976).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (976).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (976).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (979).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (979).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (979).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (98).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (98).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (98).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (980).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (980).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (980).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (981).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (981).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (981).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (982).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (982).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (982).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (984).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (984).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (984).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (985).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (985).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (985).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (988).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (988).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (988).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (989).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (989).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (989).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (99).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (99).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (99).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (990).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (990).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (990).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (991).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (991).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (991).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (992).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (992).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (992).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (994).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (994).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (994).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (996).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (996).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (996).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (997).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (997).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (997).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (998).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (998).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (998).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_0_Tumor- (999).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_1_Tumor- (999).jpg
# Saved: artifacts\data_transformation\split\train\Tumor\aug_2_Tumor- (999).jpg
# Augmentation complete.
